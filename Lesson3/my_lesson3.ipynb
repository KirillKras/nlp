# %%
import pandas as pd

# %%
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

# %%
tweets = pd.read_pickle('../tweets.df')
tweets.head()
# Out:
#     label                                              tweet  \
# id
# 1     0.0   @user when a father is dysfunctional and is s...
# 2     0.0  @user @user thanks for #lyft credit i can't us...
# 3     0.0                                bihday your majesty
# 4     0.0  #model   i love u take with u all the time in ...
# 5     0.0             factsguide: society now    #motivation
#
#                                           clean_tweet  \
# id
# 1   when father is dysfunctional and is so selfish...
# 2   thanks for lyft credit can not use cause they ...
# 3                                 bihday your majesty
# 4             model love take with all the time in ur
# 5                   factsguide society now motivation
#
#                                           tweet_token  \
# id
# 1   [when, father, is, dysfunctional, and, is, so,...
# 2   [thanks, for, lyft, credit, can, not, use, cau...
# 3                             [bihday, your, majesty]
# 4   [model, love, take, with, all, the, time, in, ur]
# 5              [factsguide, society, now, motivation]
#
#                                  tweet_token_filtered  \
# id
# 1   [father, dysfunctional, selfish, drags, kids, ...
# 2   [thanks, lyft, credit, use, cause, offer, whee...
# 3                                   [bihday, majesty]
# 4                       [model, love, take, time, ur]
# 5                   [factsguide, society, motivation]
#
#                                         tweet_stemmed  \
# id
# 1   [father, dysfunct, selfish, drag, kid, dysfunc...
# 2   [thank, lyft, credit, use, caus, offer, wheelc...
# 3                                   [bihday, majesti]
# 4                       [model, love, take, time, ur]
# 5                         [factsguid, societi, motiv]
#
#                                       tweet_lemmatize
# id
# 1   [father, dysfunctional, selfish, drag, kid, dy...
# 2   [thanks, lyft, credit, use, cause, offer, whee...
# 3                                   [bihday, majesty]
# 4                       [model, love, take, time, ur]
# 5                   [factsguide, society, motivation]

# %% [markdown]
# #### Задание 1

# %%
import spacy
from spacy import displacy
import en_core_web_md
from collections import defaultdict

# %%
nlp = en_core_web_md.load()

# %%
ner_dict = defaultdict(int)

for tweet in tweets['clean_tweet']:
    doc = nlp(tweet)
    for ent in doc.ents:
        ner_dict[ent.label_] += 1

# %%
[(k,v) for k, v in sorted(ner_dict.items(), key=lambda x: x[1], reverse=True)]
# Out:
# [('PERSON', 11639),
#  ('DATE', 10851),
#  ('ORG', 8170),
#  ('GPE', 5393),
#  ('TIME', 2295),
#  ('NORP', 1704),
#  ('CARDINAL', 1079),
#  ('ORDINAL', 583),
#  ('FAC', 364),
#  ('PRODUCT', 328),
#  ('LOC', 282),
#  ('EVENT', 218),
#  ('WORK_OF_ART', 105),
#  ('QUANTITY', 56),
#  ('LANGUAGE', 39),
#  ('MONEY', 19),
#  ('LAW', 11),
#  ('PERCENT', 4)]

# %%
pers = defaultdict(int)
org = defaultdict(int)

for tweet in tweets['clean_tweet']:
    doc = nlp(tweet)
    for ent in doc.ents:
        if ent.label_ == 'PERSON':
            pers[ent.text] += 1
        if ent.label_ == 'ORG':
            org[ent.text] += 1

# %%
[(k,v) for k, v in sorted(pers.items(), key=lambda x: x[1], reverse=True)][:15]
# Out:
# [('bing bong bing bong', 107),
#  ('suppo', 70),
#  ('obama', 66),
#  ('hillary', 55),
#  ('sta', 46),
#  ('feminismiscancer feminismisterrorism feminismmuktbharat', 40),
#  ('melancholy melancholymusic', 40),
#  ('bjp', 36),
#  ('christina grimmie', 34),
#  ('hu', 31),
#  ('jo cox', 27),
#  ('tgif ff', 26),
#  ('gamedev indiedev indiegamedev', 25),
#  ('lebron', 25),
#  ('sea shepherd suppoers', 25)]

# %%
[(k,v) for k, v in sorted(org.items(), key=lambda x: x[1], reverse=True)][:15]
# Out:
# [('sjw', 102),
#  ('allahsoil', 84),
#  ('gop', 76),
#  ('nba', 59),
#  ('islam', 53),
#  ('trump', 49),
#  ('ht', 43),
#  ('facebook', 40),
#  ('cavs', 39),
#  ('bihday', 38),
#  ('social analytics', 34),
#  ('cnn', 30),
#  ('obama', 30),
#  ('ios', 30),
#  ('wso', 28)]

# %% [markdown]
# #### Задание 2

# %%
import nltk
nltk.download('averaged_perceptron_tagger')
nltk.download('maxent_ne_chunker')
nltk.download('words')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/kosmosivanov/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /Users/kosmosivanov/nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package words to
# [nltk_data]     /Users/kosmosivanov/nltk_data...
# [nltk_data]   Unzipping corpora/words.zip.
# True

# %%
for tweet in tweets['clean_tweet'].iloc[:100]:
    res = {(' '.join(c[0] for c in chunk), chunk.label() ) for chunk in
           nltk.ne_chunk(nltk.pos_tag(nltk.word_tokenize(tweet))) if hasattr(chunk, 'label') }
    print(res)
# Out:
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()

# %%
for tweet in tweets['clean_tweet'].iloc[:100]:
    res = nltk.ne_chunk(nltk.pos_tag(nltk.word_tokenize(tweet)), binary=False)
    print(res)
# Out:
# (S
#   when/WRB
#   father/NN
#   is/VBZ
#   dysfunctional/JJ
#   and/CC
#   is/VBZ
#   so/RB
#   selfish/JJ
#   he/PRP
#   drags/VBZ
#   his/PRP$
#   kids/NNS
#   into/IN
#   his/PRP$
#   dysfunction/NN
#   run/VB)
# (S
#   thanks/NNS
#   for/IN
#   lyft/JJ
#   credit/NN
#   can/MD
#   not/RB
#   use/VB
#   cause/NN
#   they/PRP
#   do/VBP
#   not/RB
#   offer/VB
#   wheelchair/NN
#   vans/NNS
#   in/IN
#   pdx/NN
#   disapointed/VBN
#   getthanked/VBD)
# (S bihday/RB your/PRP$ majesty/NN)
# (S
#   model/NN
#   love/NNS
#   take/VBP
#   with/IN
#   all/PDT
#   the/DT
#   time/NN
#   in/IN
#   ur/JJ)
# (S factsguide/JJ society/NN now/RB motivation/NN)
# (S
#   huge/JJ
#   fan/NN
#   fare/NN
#   and/CC
#   big/JJ
#   talking/VBG
#   before/IN
#   they/PRP
#   leave/VBP
#   chaos/NNS
#   and/CC
#   pay/VB
#   disputes/NNS
#   when/WRB
#   they/PRP
#   get/VBP
#   there/RB
#   allshowandnogo/RB)
# (S camping/VBG tomorrow/NN danny/NN)
# (S
#   the/DT
#   next/JJ
#   school/NN
#   year/NN
#   is/VBZ
#   the/DT
#   year/NN
#   for/IN
#   exams/NNS
#   can/MD
#   not/RB
#   think/VB
#   about/IN
#   that/DT
#   school/NN
#   exams/RB
#   hate/VBP
#   imagine/JJ
#   actorslife/NN
#   revolutionschool/NN
#   girl/NN)
# (S
#   we/PRP
#   won/VBD
#   love/VB
#   the/DT
#   land/NN
#   allin/NN
#   cavs/NN
#   champions/NNS
#   cleveland/VBP
#   clevelandcavaliers/NNS)
# (S welcome/NN here/RB it/PRP so/RB gr/JJ)
# (S
#   ireland/VB
#   consumer/NN
#   price/NN
#   index/NN
#   mom/VBD
#   climbed/VBN
#   from/IN
#   previous/JJ
#   to/TO
#   in/IN
#   may/MD
#   blog/VB
#   silver/VB
#   gold/NN
#   forex/NN)
# (S
#   we/PRP
#   are/VBP
#   so/RB
#   selfish/JJ
#   orlando/NN
#   standwithorlando/NN
#   pulseshooting/VBG
#   orlandoshooting/VBG
#   biggerproblems/NNS
#   selfish/JJ
#   heabreaking/VBG
#   values/NNS
#   love/VB)
# (S
#   get/NN
#   to/TO
#   see/VB
#   my/PRP$
#   daddy/JJ
#   today/NN
#   days/NNS
#   gettingfed/VBD)
# (S
#   cnn/NN
#   calls/VBZ
#   michigan/JJ
#   middle/JJ
#   school/NN
#   build/VBP
#   the/DT
#   wall/NN
#   chant/NN
#   tcot/NN)
# (S
#   no/DT
#   comment/NN
#   in/IN
#   australia/JJ
#   opkillingbay/JJ
#   seashepherd/NN
#   helpcovedolphins/NNS
#   thecove/VBP
#   helpcovedolphins/NNS)
# (S
#   ouch/JJ
#   junior/NN
#   is/VBZ
#   angry/JJ
#   got/VBD
#   junior/JJ
#   yugyoem/NN
#   omg/NN)
# (S
#   am/VBP
#   thankful/NN
#   for/IN
#   having/VBG
#   paner/NN
#   thankful/JJ
#   positive/JJ)
# (S retweet/NN if/IN you/PRP agree/VBP)
# (S
#   its/PRP$
#   friday/JJ
#   smiles/NNS
#   all/DT
#   around/IN
#   via/IN
#   ig/NN
#   user/NN
#   cookies/NNS
#   make/VBP
#   people/NNS)
# (S
#   as/IN
#   we/PRP
#   all/DT
#   know/VBP
#   essential/JJ
#   oils/NNS
#   are/VBP
#   not/RB
#   made/VBN
#   of/IN
#   chemicals/NNS)
# (S
#   euro/JJ
#   people/NNS
#   blaming/VBG
#   ha/NN
#   for/IN
#   conceded/JJ
#   goal/NN
#   was/VBD
#   it/PRP
#   fat/JJ
#   rooney/NN
#   who/WP
#   gave/VBD
#   away/RB
#   free/JJ
#   kick/NN
#   knowing/VBG
#   bale/NN
#   can/MD
#   hit/VB
#   them/PRP
#   from/IN
#   there/EX)
# (S
#   sad/JJ
#   little/JJ
#   dude/NN
#   badday/NN
#   coneofshame/NN
#   cats/NNS
#   pissed/VBD
#   funny/JJ
#   laughs/NNS)
# (S
#   product/NN
#   of/IN
#   the/DT
#   day/NN
#   happy/JJ
#   man/NN
#   wine/NN
#   tool/NN
#   who/WP
#   it/PRP
#   the/DT
#   weekend/NN
#   time/NN
#   to/TO
#   open/VB
#   up/RP
#   drink/VB
#   up/RP)
# (S lumpy/NN says/VBZ am/VBP prove/VB it/PRP lumpy/JJ)
# (S
#   tgif/NN
#   ff/NN
#   to/TO
#   my/PRP$
#   gamedev/NN
#   indiedev/NN
#   indiegamedev/NN
#   squad/NN)
# (S
#   beautiful/JJ
#   sign/NN
#   by/IN
#   vendor/NN
#   for/IN
#   upsideofflorida/JJ
#   shopalyssas/NNS
#   love/VBP)
# (S
#   all/DT
#   smiles/NNS
#   when/WRB
#   media/NNS
#   is/VBZ
#   pressconference/NN
#   in/IN
#   antalya/JJ
#   turkey/NN
#   sunday/JJ
#   throwback/NN
#   love/NN)
# (S
#   we/PRP
#   had/VBD
#   great/JJ
#   panel/NN
#   on/IN
#   the/DT
#   mediatization/NN
#   of/IN
#   the/DT
#   public/JJ
#   service/NN
#   ica/NN)
# (S happy/JJ father/NN day/NN)
# (S
#   people/NNS
#   went/VBD
#   to/TO
#   nightclub/VB
#   to/TO
#   have/VB
#   good/JJ
#   night/NN
#   and/CC
#   man/NN
#   actions/NNS
#   means/VBZ
#   those/DT
#   people/NNS
#   are/VBP
#   lost/VBN
#   to/TO
#   their/PRP$
#   families/NNS
#   forever/RB
#   rip/VBP
#   orlando/NN)
# (S
#   have/VB
#   never/RB
#   had/VBN
#   chance/NN
#   to/TO
#   vote/VB
#   for/IN
#   presidential/JJ
#   candidate/NN
#   was/VBD
#   excited/VBN
#   about/RB
#   and/CC
#   this/DT
#   cycle/NN
#   looks/VBZ
#   to/TO
#   be/VB
#   no/DT
#   different/JJ)
# (S
#   alohafriday/JJ
#   time/NN
#   does/VBZ
#   not/RB
#   exist/VB
#   positivevibes/NNS
#   hawaiian/JJ)
# (S
#   rip/NN
#   to/TO
#   the/DT
#   fellow/JJ
#   nohern/JJ
#   ireland/NN
#   fan/NN
#   who/WP
#   sadley/VBP
#   passed/VBN
#   away/RB
#   tonight/JJ
#   gawa/NN
#   forever/NN
#   singing/NN
#   and/CC
#   cheering/VBG
#   on/IN
#   fire/NN)
# (S
#   it/PRP
#   was/VBD
#   hard/JJ
#   monday/NN
#   due/JJ
#   to/TO
#   cloudy/VB
#   weather/NN
#   disabling/VBG
#   oxygen/NN
#   production/NN
#   for/IN
#   today/NN
#   goodnight/VBD
#   badmonday/NN)
# (S
#   it/PRP
#   unbelievable/JJ
#   that/IN
#   in/IN
#   the/DT
#   st/JJ
#   century/NN
#   we/PRP
#   need/VBP
#   something/NN
#   like/IN
#   this/DT
#   again/RB
#   neverump/JJ
#   xenophobia/NN)
# (S
#   taylorswift/NN
#   bull/VB
#   up/IN
#   you/PRP
#   will/MD
#   dominate/VB
#   your/PRP$
#   bull/NN
#   and/CC
#   you/PRP
#   will/MD
#   direct/VB
#   it/PRP
#   whatever/WDT
#   you/PRP
#   want/VBP
#   it/PRP
#   to/TO
#   do/VB)
# (S morning/NN travelingram/NN dalat/NN ripinkylife/NN)
# (S
#   once/RB
#   more/JJR
#   only/RB
#   one/CD
#   word/NN
#   tells/VBZ
#   it/PRP
#   all/DT
#   photoshop/VBP
#   enoughisenough/IN
#   dontphotoshopeverything/VBG
#   wheresallthenaturalphotos/NN)
# (S
#   oh/UH
#   cedarpoint/NN
#   waited/VBD
#   hours/NNS
#   in/IN
#   the/DT
#   valravn/NN
#   line/NN
#   and/CC
#   it/PRP
#   stopped/VBD
#   working/VBG
#   we/PRP
#   were/VBD
#   so/RB
#   close/JJ)
# (S am/VBP thankful/JJ for/IN sunshine/JJ thankful/JJ positive/JJ)
# (S
#   when/WRB
#   you/PRP
#   finally/RB
#   finish/VB
#   book/NN
#   you/PRP
#   ve/VBP
#   been/VBN
#   working/VBG
#   on/IN
#   for/IN
#   awhile/JJ
#   bookworm/NN
#   ontothenextnovel/NN)
# (S
#   yup/NN
#   being/VBG
#   knicks/NNS
#   fan/NN
#   is/VBZ
#   hard/JJ
#   so/IN
#   its/PRP$
#   easier/JJR
#   to/TO
#   just/RB
#   be/VB
#   an/DT
#   nba/JJ
#   fan/NN
#   when/WRB
#   the/DT
#   playoffs/NNS
#   roll/VBP
#   around/RB)
# (S
#   there/EX
#   is/VBZ
#   life/NN
#   after/IN
#   social/JJ
#   networking/JJ
#   embrace/NN
#   each/DT
#   day/NN
#   be/VB)
# (S
#   my/PRP$
#   mom/NN
#   shares/NNS
#   the/DT
#   same/JJ
#   bihday/NN
#   as/IN
#   bihday/JJ
#   snake/VBP
#   see/VB
#   you/PRP
#   this/DT
#   weekend/NN)
# (S
#   lovely/RB
#   echeveria/JJ
#   blooms/NNS
#   flowers/NNS
#   grow/VBP
#   gardening/VBG
#   iphonesia/NN
#   bliss/NN
#   blooms/NNS
#   basilicabotanica/VBP)
# (S am/VBP amazing/VBG am/VBP positive/JJ affirmation/NN)
# (S
#   model/NN
#   love/NNS
#   take/VBP
#   with/IN
#   all/PDT
#   the/DT
#   time/NN
#   in/IN
#   ur/JJ)
# (S whenever/WRB im/NN and/CC something/NN goes/VBZ wrong/JJ)
# (S feeling/VBG blue/JJ illustration/NN)
# (S
#   the/DT
#   best/JJS
#   pa/NN
#   about/IN
#   life/NN
#   is/VBZ
#   knowing/VBG
#   who/WP
#   you/PRP
#   are/VBP)
# (S
#   abc/IN
#   getting/VBG
#   ready/JJ
#   remove/VB
#   the/DT
#   victums/NNS
#   frm/VBP
#   pulseclub/JJ
#   prayfororlando/NN)
# (S
#   for/IN
#   her/PRP$
#   bihday/NN
#   we/PRP
#   got/VBD
#   her/PRP
#   nose/JJ
#   job/NN
#   bihday/JJ
#   petunia/IN
#   we/PRP
#   love/VBP
#   you/PRP)
# (S
#   off/IN
#   to/TO
#   concelebrate/VB
#   at/IN
#   the/DT
#   albanpilgrimage/NN
#   for/IN
#   the/DT
#   first/JJ
#   time/NN)
# (S let/VB the/DT scum/JJ baggery/NN begin/NN)
# (S
#   thank/NN
#   you/PRP
#   super/VBP
#   love/VB
#   it/PRP
#   zpamdelacruz/RP
#   wedding/VBG
#   dolores/NNS
#   capas/VBP
#   tarlac/NN)
# (S
#   scourge/NN
#   on/IN
#   those/DT
#   playing/VBG
#   baroque/JJ
#   pieces/NNS
#   on/IN
#   piano/NN
#   beyond/IN
#   belief/NN)
# (S lets/NNS fight/VBN against/IN love/NN peace/NN)
# (S
#   happy/JJ
#   father/NN
#   day/NN
#   mr/VBD
#   rayos/JJ
#   video/NN
#   fathers/NNS
#   day/NN
#   rayos/VBP
#   world/NN
#   hotvideo/NN
#   videos/NN)
# (S
#   ascot/JJ
#   times/NNS
#   with/IN
#   this/DT
#   babe/NN
#   ascot/VBZ
#   fashion/NN
#   monochrome/JJ
#   style/NN
#   instahappyday/NN)
# (S
#   the/DT
#   weekend/NN
#   is/VBZ
#   here/RB
#   selfie/JJ
#   yolo/RB
#   xoxo/VBP
#   like/IN
#   like/IN)
# (S
#   happy/JJ
#   at/IN
#   work/NN
#   conference/NN
#   right/JJ
#   mindset/NN
#   leads/VBZ
#   to/TO
#   culture/NN
#   of/IN
#   development/NN
#   organizations/NNS
#   work/VBP
#   mindset/NN)
# (S
#   christina/NN
#   grimmie/NN
#   last/JJ
#   performance/NN
#   before/IN
#   being/VBG
#   shot/JJ
#   via/IN
#   christinarip/JJ
#   voice/NN
#   christinagrimmie/NN)
# (S
#   we/PRP
#   are/VBP
#   ready/JJ
#   to/TO
#   dance/VB
#   roar/NN
#   preschoolers/NNS
#   students/NNS
#   proud/VBP)
# (S you/PRP ve/VBP really/RB hu/JJ my/PRP$ feelings/NNS)
# (S
#   my/PRP$
#   wife/NN
#   whom/WP
#   adore/RB
#   had/VBD
#   to/TO
#   miss/VB
#   your/PRP$
#   poland/NN
#   show/NN
#   because/IN
#   she/PRP
#   had/VBD
#   surgery/NN
#   her/PRP$
#   name/NN
#   is/VBZ
#   bridget/IN
#   she/PRP
#   my/PRP$
#   everything/NN)
# (S am/VBP so/RB jealous/JJ of/IN you/PRP right/RB now/RB chatiado/VB)
# (S
#   celebrate/NN
#   every/DT
#   man/NN
#   that/WDT
#   has/VBZ
#   played/VBN
#   it/PRP
#   fatherly/RB
#   role/NN
#   father/NN
#   day/NN)
# (S sure/NN they/PRP are/VBP just/RB as/IN happy/JJ hour/NN)
# (S
#   the/DT
#   white/JJ
#   establishment/NN
#   can/MD
#   not/RB
#   have/VB
#   blk/VBN
#   folx/JJ
#   running/VBG
#   around/RB
#   loving/VBG
#   themselves/PRP
#   and/CC
#   promoting/VBG
#   our/PRP$
#   greatness/NN)
# (S
#   good/JJ
#   morning/NN
#   the/DT
#   journey/NN
#   begins/VBZ
#   travel/JJ
#   yeah/NN
#   thejourneybegins/NNS
#   hello/VBP)
# (S
#   if/IN
#   you/PRP
#   luv/VBP
#   hottweets/NNS
#   like/IN
#   this/DT
#   from/IN
#   venusexchange/NN)
# (S
#   our/PRP$
#   new/JJ
#   brochures/NNS
#   have/VBP
#   arrived/VBN
#   how/WRB
#   exciting/JJ
#   aworks/NNS
#   solutions/NNS)
# (S
#   so/RB
#   much/JJ
#   stuff/NN
#   happening/VBG
#   in/IN
#   florida/NN
#   first/RB
#   orlando/JJ
#   shooting/NN
#   and/CC
#   now/RB
#   disneygatorattack/VB
#   on/IN
#   two/CD
#   year/NN
#   old/JJ
#   kid/NN)
# (S
#   ferrari/NN
#   will/MD
#   do/VB
#   it/PRP
#   for/IN
#   the/DT
#   sake/NN
#   of/IN
#   the/DT
#   championship/NN
#   this/DT
#   gp/NN
#   is/VBZ
#   clearly/RB
#   turning/VBG
#   point/NN
#   rb/NN
#   ferrari/NN
#   mercs/NN)
# (S aced/JJ my/PRP$ first/JJ test/NN proud/NN)
# (S
#   seeks/NN
#   probe/NN
#   into/IN
#   udtapunjab/JJ
#   leak/JJ
#   points/NNS
#   finger/NN
#   at/IN
#   amarinder/NN
#   aap/NN)
# (S wrapping/VBG up/RP senseaboutmaths/NNS th/IN)
# (S
#   hey/JJ
#   white/JJ
#   people/NNS
#   you/PRP
#   can/MD
#   call/VB
#   people/NNS
#   white/JJ
#   by/IN
#   race/NN
#   identity/NN
#   med/VBD)
# (S
#   you/PRP
#   might/MD
#   be/VB
#   just/RB
#   have/VB
#   not/RB
#   shown/VBN
#   here/RB
#   today/NN
#   regurgitated/VBD
#   talking/VBG
#   points/NNS
#   and/CC
#   name/NN
#   calling/VBG)
# (S
#   sometimes/RB
#   you/PRP
#   have/VBP
#   to/TO
#   raise/VB
#   few/JJ
#   brows/NNS
#   to/TO
#   raise/VB
#   the/DT
#   bar/NN
#   golfstrengthandconditioning/NN
#   strong/JJ
#   felixfoisgolf/NN)
# (S about/IN that/DT greathonour/NN careerconvos/NN)
# (S
#   designing/VBG
#   innovative/JJ
#   learning/VBG
#   space/NN
#   to/TO
#   include/VB
#   wateringhole/JJ
#   cave/JJ
#   mountaintop/NN
#   campfire/NN)
# (S
#   how/WRB
#   the/DT
#   altright/JJ
#   uses/NNS
#   insecurity/NN
#   to/TO
#   lure/VB
#   men/NNS
#   into/IN
#   whitesupremacy/NN)
# (S
#   carrying/VBG
#   gun/NN
#   wouldn/NN
#   of/IN
#   helped/NN
#   if/IN
#   you/PRP
#   can/MD
#   not/RB
#   take/VB
#   it/PRP
#   in/IN
#   with/IN
#   you/PRP
#   gun/VBP
#   control/VB
#   won/VBD
#   stop/VB
#   the/DT
#   black/JJ
#   market/NN
#   terrorism/NN
#   will/MD
#   get/VB
#   worse/JJR)
# (S
#   use/VB
#   the/DT
#   power/NN
#   of/IN
#   your/PRP$
#   mind/NN
#   to/TO
#   heal/VB
#   your/PRP$
#   body/NN
#   altwaystoheal/JJ
#   healthy/JJ
#   peace/NN)
# (S woohoo/NN just/RB over/IN weeks/NNS to/TO go/VB)
# (S
#   being/VBG
#   in/IN
#   far/RB
#   away/RB
#   place/NN
#   where/WRB
#   you/PRP
#   have/VBP
#   no/DT
#   family/NN
#   members/NNS
#   hus/VBP)
# (S
#   ready/JJ
#   to/TO
#   rehearse/VB
#   tonight/NN
#   with/IN
#   new/JJ
#   music/NN
#   and/CC
#   new/JJ
#   videos/NNS
#   look/VBP
#   out/RP
#   for/IN
#   the/DT
#   announcement/NN
#   midweek/NN
#   newmusic/JJ
#   watchthisspace/NN
#   guitar/NN)
# (S
#   now/RB
#   on/IN
#   monday/JJ
#   nights/NNS
#   at/IN
#   pm/NN
#   on/IN
#   up/IN
#   channel/NNS
#   finally/RB
#   get/VB
#   to/TO
#   see/VB
#   what/WP
#   all/PDT
#   the/DT
#   fuss/NN
#   is/VBZ
#   about/IN)
# (S watching/VBG the/DT new/JJ episodes/NNS of/IN on/IN)
# (S
#   offline/NN
#   now/RB
#   after/IN
#   very/RB
#   nice/JJ
#   and/CC
#   long/JJ
#   night/NN
#   snapchat/WP
#   redhead/NN
#   vermillionred/VBD)
# (S things/NNS incredibly/RB people/NNS do/VBP)
# (S
#   yes/RB
#   received/VBN
#   my/PRP$
#   acceptance/NN
#   letter/NN
#   for/IN
#   my/PRP$
#   masters/NNS
#   so/RB
#   will/MD
#   be/VB
#   back/RB
#   at/IN
#   again/RB
#   in/IN
#   october/JJ
#   goodtimes/NNS
#   history/NN)
# (S
#   daughter/NN
#   riding/VBG
#   her/PRP$
#   bike/NN
#   around/IN
#   driveway/RB
#   son/JJ
#   playing/VBG
#   his/PRP$
#   guitar/NN
#   for/IN
#   us/PRP
#   while/IN
#   we/PRP
#   enjoy/VBP
#   by/IN
#   the/DT
#   campfire/NN
#   summeime/NN
#   memories/NNS)
# (S
#   omg/RB
#   loving/VBG
#   this/DT
#   station/NN
#   way/NN
#   to/TO
#   jam/VB
#   out/RP
#   at/IN
#   work/NN
#   while/IN
#   getting/VBG
#   work/NN
#   done/VBN
#   of/IN
#   course/NN
#   memories/NNS)
# (S
#   ll/NN
#   always/RB
#   hope/VBP
#   that/IN
#   one/CD
#   day/NN
#   ll/VBZ
#   get/VB
#   to/TO
#   hug/VB
#   you/PRP
#   but/CC
#   do/VBP
#   not/RB
#   think/VB
#   that/IN
#   it/PRP
#   gon/VBZ
#   na/TO
#   happen/VB
#   anytime/RB
#   soon/RB)
# (S
#   model/NN
#   love/NNS
#   take/VBP
#   with/IN
#   all/PDT
#   the/DT
#   time/NN
#   in/IN
#   ur/JJ)
# (S couple/NN having/VBG sex/NN fat/JJ naked/JJ japanese/JJ girls/NNS)
# (S
#   hump/NN
#   on/IN
#   that/DT
#   hump/NN
#   day/NN
#   humpers/NNS
#   edwardsville/VBP
#   pennsylvania/NN)
# (S
#   personalised/VBN
#   we/PRP
#   gbp/VBP
#   get/VB
#   here/RB
#   shop/JJ
#   cool/JJ
#   home/NN
#   fun/NN)
